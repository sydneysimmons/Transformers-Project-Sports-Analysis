# %%
from transformers import AutoTokenizer, AutoModelForTableQuestionAnswering

tokenizer = AutoTokenizer.from_pretrained("google/tapas-base-finetuned-wtq")

model = AutoModelForTableQuestionAnswering.from_pretrained("google/tapas-base-finetuned-wtq")

# %% [markdown]
# # Installs

# %%
# !pip install -q transformers==4.4.2

# %%
import torch
torch.__version__
# Out:
# '1.13.0'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.0.tar.gz (106 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... done
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.0-cp39-cp39-macosx_10_9_x86_64.whl size=353673 sha256=b85b803c9c465a93f208420f40ca43e055f5cdd103ffa8c163cedef79048b68e
#   Stored in directory: /Users/donaldkane/Library/Caches/pip/wheels/bf/08/9d/28fef90c720e723909a15628bda60b030ebe174780c129a040
# Successfully built torch-scatter
# Installing collected packages: torch-scatter
# Successfully installed torch-scatter-2.1.0

# %% [markdown]
# # Imports

# %%
from transformers import pipeline
import pandas as pd

# %%
tqa = pipeline(task="table-question-answering", 
               model="google/tapas-base-finetuned-wtq")

# %% [markdown]
# # Reading Data

# %%
table = pd.read_csv("/Users/donaldkane/Desktop/Transformers-Project-Sports-Analysis/TableQuestionAnswering/superbowl.csv")
table = table.astype(str)

# %%
table
# Out:
#                Player Team Completions Pass Attempts Passing Yards Touchdowns  \
# 0          Joe Burrow  CIN          22            33           263          1
# 1           Joe Mixon  CIN           1             1             6          1
# 2       Ja'Marr Chase  CIN           0             0             0          0
# 3         Tee Higgins  CIN           0             0             0          0
# 4          Tyler Boyd  CIN           0             0             0          0
# 5         Mike Thomas  CIN           0             0             0          0
# 6         C.J. Uzomah  CIN           0             0             0          0
# 7         Chris Evans  CIN           0             0             0          0
# 8       Samaje Perine  CIN           0             0             0          0
# 9    Matthew Stafford  LAR          26            40           283          3
# 10        Cooper Kupp  LAR           0             1             0          0
# 11          Cam Akers  LAR           0             0             0          0
# 12  Darrell Henderson  LAR           0             0             0          0
# 13        Sony Michel  LAR           0             0             0          0
# 14  Odell Beckham Jr.  LAR           0             0             0          0
# 15     Brycen Hopkins  LAR           0             0             0          0
# 16      Van Jefferson  LAR           0             0             0          0
# 17      Ben Skowronek  LAR           0             0             0          0
#
#    Interceptions Sacks Yds Lng  ... Rushing Yards Rushing Touchdwons Lng.1  \
# 0              0     7  43  75  ...             3                  0     4
# 1              0     0   0   6  ...            72                  0    14
# 2              0     0   0   0  ...             4                  0     4
# 3              0     0   0   0  ...             0                  0     0
# 4              0     0   0   0  ...             0                  0     0
# 5              0     0   0   0  ...             0                  0     0
# 6              0     0   0   0  ...             0                  0     0
# 7              0     0   0   0  ...             0                  0     0
# 8              0     0   0   0  ...             0                  0     0
# 9              2     2  13  35  ...             6                  0     7
# 10             0     0   0   0  ...             7                  0     7
# 11             0     0   0   0  ...            21                  0     8
# 12             0     0   0   0  ...             7                  0     5
# 13             0     0   0   0  ...             2                  0     3
# 14             0     0   0   0  ...             0                  0     0
# 15             0     0   0   0  ...             0                  0     0
# 16             0     0   0   0  ...             0                  0     0
# 17             0     0   0   0  ...             0                  0     0
#
#    Targets Receptions Receiving Yards TDs Lng.2 Fumbles FL
# 0        0          0               0   0     0       0  0
# 1        6          5               1   0     4       0  0
# 2        8          5              89   0    46       0  0
# 3        7          4             100   2    75       0  0
# 4        6          5              48   0    16       0  0
# 5        1          1              17   0    17       0  0
# 6        2          2              11   0     6       0  0
# 7        2          1               3   0     3       0  0
# 8        1          0               0   0     0       0  0
# 9        1          0               0   0     0       0  0
# 10      10          8              92   2    22       0  0
# 11       4          3              14   0     7       0  0
# 12       5          3              43   0    25       0  0
# 13       0          0               0   0     0       0  0
# 14       3          2              52   1    35       0  0
# 15       4          4              47   0    16       0  0
# 16       8          4              23   0    13       0  0
# 17       5          2              12   0     7       0  0
#
# [18 rows x 22 columns]

# %% [markdown]
# # Superbowl

# %%
query = "How many passing yards did Stafford have?"
print(tqa(table=table, query=query)["answer"])
# Out:
# SUM > 283

# %%
query = ["Matthew Stafford touchdowns?", 
         "Which team does Stafford play for?"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# SUM > 3
# LAR

# %%
query = ["Tee Higgins Tds?", 
         "How many receiving yards did Higgins have?"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# SUM > 2
# SUM > 100

# %%
query = ["How many yards did Burrow throw for?", 
         "Which team did he play for?"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# AVERAGE > 263
# CIN

# %%
query = "How many people had over 1 passing yards?"
print(tqa(table=table, query=query)["answer"])
# Out:
# COUNT > Joe Burrow, Joe Mixon, Matthew Stafford

# %% [markdown]
# # Training

# %%
import sagemaker
import boto3
from sagemaker.huggingface import HuggingFace

# gets role for executing training job
iam_client = boto3.client('iam')
role = iam_client.get_role(RoleName='{IAM_ROLE_WITH_SAGEMAKER_PERMISSIONS}')['Role']['Arn']
hyperparameters = {
    'model_name_or_path':'google/tapas-base-finetuned-wtq',
    'output_dir':'/opt/ml/model'
    # add your remaining hyperparameters
    
    # more info here https://github.com/huggingface/transformers/tree/v4.17.0/examples/pytorch/question-answering
}

# git configuration to download our fine-tuning script
git_config = {'repo': 'https://github.com/huggingface/transformers.git','branch': 'v4.17.0'}

# creates Hugging Face estimator
huggingface_estimator = HuggingFace(
    entry_point='run_qa.py',
    source_dir='./examples/pytorch/question-answering',
    instance_type='ml.p3.2xlarge',
    instance_count=1,
    role=role,
    git_config=git_config,
    transformers_version='4.17.0',
    pytorch_version='1.10.2',
    py_version='py38',
    hyperparameters = hyperparameters
)

# starting the train job
huggingface_estimator.fit()
